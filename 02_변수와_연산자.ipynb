# %% [markdown]
# <a href="https://colab.research.google.com/github/deartoms/python/blob/main/02_%E1%84%87%E1%85%A7%E1%86%AB%E1%84%89%E1%85%AE%E1%84%8B%E1%85%AA_%E1%84%8B%E1%85%A7%E1%86%AB%E1%84%89%E1%85%A1%E1%86%AB%E1%84%8C%E1%85%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 파이썬 기초: 02. 변수와 연산자

# %% [markdown]
# ## 1. 변수 (Variable)
#
# * **개념**: 프로그램 실행 중 값을 저장하는 메모리 공간.
# * **특징**: 변수에는 하나의 값만 저장되며, 새로운 값을 넣으면 기존 값은 삭제됨.
# * **대입 연산자 (`=`)**: 오른쪽의 값을 왼쪽 변수에 저장함.
# * 예: `age = 20` (age라는 변수에 20을 대입)

# %%
age = 20
print(age)
# Out:
# 20

# %%
age = 20
print('age')
# Out:
# age

# %%
age = 20
print(age)

age = 21
print(age)
# Out:
# 20
# 21

# %%
name = '홍길동'
age = 18
print(name, '나이:', age)
# Out:
# 홍길동 나이: 18

# %%
a = b = c = 7
print(a, b, c)
# Out:
# 7 7 7

# %%
a, b, c = 7, 11, 19
print(a, b, c)
# Out:
# 7 11 19

# %% [markdown]
# ### 복합 대입 연산자
#
#
#
#
# *   복합 대입 연산자: 연산한 값을 다시 대입하는 연산자
#
# *   a += b 는 a = a+b 이다
#
# *   += : 왼쪽 값에 오른쪽 값을 더한 결과를 다시 왼쪽에 대입
#
# * -= : 왼쪽 값에서 오른쪽 값을 뺀 결과를 다시 왼쪽에 대입

# %%
a = 5
a += 7
print(a)
# Out:
# 12

# %%
a, b = 2, 3
a += b
print(a)

a, b = 2, 3
a -= b
print(a)
# Out:
# 5
# -1

# %%
a, b = 2, 3
a *= b
print(a)

a, b = 3, 2
a /= b
print(a)

a, b = 7, 3
a //=b # a = a // b 몫
print(a)

a, b = 7, 3
a %= b # a = a % b 나머지
print(a)
# Out:
# 6
# 1.5
# 2
# 1

# %%
a = 100
a += 10
print(a)

a *= 2
print(a)

a //= 7
print(a)

a %=7
print(a)
# Out:
# 110
# 220
# 31
# 3

# %% [markdown]
# ### 변수 이름의 규칙
# * 변수 이름을 만들 때의 규칙
# -첫번째 글자는 문자 또는 밑줄이어야하고
#
# -나머지 글자는 문자,숫자,밑줄이어야함
#
# -영문 대문자와 영문 소문자는 구분
#
# -키워드(예약어)를 변수 이름으로 사용할 수 없음
#
# 키워드(keyword): 프로그래밍 언어에서 사용하기 위해 쓰임새를 미리 정해 놓은 단어

# %%
# 두 변수의 값 교환하기
a = 7
b = 11
a, b = b, a
print(a, b)
# Out:
# 11 7

# %%
a = 3
print(a)

a += 3
print(a)

a += 3
print(a)
# Out:
# 3
# 6
# 9

# %% [markdown]
# ## 2. 자료형 (Data Type)
#
# 데이터의 종류에 따라 적절한 자료형을 사용해야 합니다.
#
# * **정수형 (int)**: 소수점이 없는 숫자 (예: 10, -5)
# * **실수형 (float)**: 소수점이 있는 숫자 (예: 3.14, 0.5)
# * **문자열 (str)**: 따옴표(`'`, `"`)로 감싸진 텍스트 (예: "Hello", 'Python')
# * **불형 (bool)**: 참(`True`) 또는 거짓(`False`)을 나타냄

# %%
print(type(2026))
print(type(3.14))
print(type('Python'))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = 20
b = 0o34
c = 0xA1
d = 0b1110
print(a, b, c, d)
# Out:
# 20 28 161 14

# %%
a = 3.14
b = 1.23e5
c = 123000.0e-5
print(a, b, c)
# Out:
# 3.14 123000.0 1.23

# %% [markdown]
# ### 자료형의 개요
#
# * 부동소수점수:3.14159265와 같이 소수점이 있는 수
#
# * 불(bool) 데이터: True(참), False(거짓)
#
# * 정수,부동소수점수,문자열, 불 등을 모두 자료형이라고 함

# %%
print('convergence' + 'programming')
print(23 - 25)
print(1.23 + 12.3e-1)
# Out:
# convergenceprogramming
# -2
# 2.46

# %% [markdown]
# ## 3. 입력과 출력
#
# * **출력 (`print`)**: 변수나 값을 화면에 표시.
# * `print('age')`는 문자열 출력, `print(age)`는 변수 값 출력.
#
# * **입력 (`input`)**: 사용자로부터 데이터를 입력받음.
# * **주의**: `input()`으로 받은 데이터는 기본적으로 **문자열**로 처리되므로, 계산이 필요하면 `int()`나 `float()`로 변환해야 함.

# %% [markdown]
# ### 입력
#
#
# *   사용자로부터 데이터를 입력받을 때 input 함수를 사용
#
# *   input 함수는 안내문을 출력하고 사용자가 입력하면 입력 데이터를 문자열에 출력받음

# %%
name = input('이름: ')
age = input('나이: ')
print(name, '나이: ', age)
# Out:
# 이름: 김태환
# 나이: 26
# 김태환 나이:  26

# %%
a = input('정수: ')
b = input('정수: ')
print(a - b)
# Out:
# 정수: 9
# 정수: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2617910764.py in <cell line: 0>()
#       1 a = input('정수: ')
#       2 b = input('정수: ')
# ----> 3 print(a - b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a = int(input('정수: '))
b = int(input('정수: '))
print(a - b)
# Out:
# 정수: 9
# 정수: 5
# 4

# %%
minute = float(input('분 단위 시간: '))
second = minute * 60
print(second, '초')
# Out:
# 분 단위 시간: 5.5
# 330.0 초

# %%
print('반갑습니다')
score = 99
print('성적은 ', score, '입니다.')
# Out:
# 반갑습니다
# 성적은  99 입니다.

# %%
a = 25
b = 42
print(a, end=' ')
print(b)
# Out:
# 25 42

# %%
print('안녕하세요')
print()
print('Python')
# Out:
# 안녕하세요
#
# Python

# %%
name = '홍길동'
age= 20
print('이름은', name, '이고 나이는', age, '입니다')
# Out:
# 이름은 홍길동 이고 나이는 20 입니다

# %% [markdown]
# ### f-문자열(f-string):
#
#
# * 불필요한 공백을 없애려면 print 함수 안에 f-문자열을 입력
#
# * f-문자열: 문자열 앞에 소문자 f 또는 대문자 F를 붙이고 문자열 안의 변수를 중괄호({})로 감싸서 표현하는 것
#
# * 변수 값이 출력되는 형식을 지정할 수 있음
# * 변수명 옆에 콜론(:)을 넣고 그 다음에 형식을 지정
# * 중괄호 안의 d는 정수를 의미하고, f는 부동소수점수를 의미

# %%
name = '홍길동'
age = 20
print(f'이름은 {name}이고 나이는 {age}입니다')
print(f'{name:5}:{age:3}')
# Out:
# 이름은 홍길동이고 나이는 20입니다

# %%
a = 25
b = 1234
c = 6
print(f'{a:5d}')
print(f'{b:5d}')
print(f'20{c:02d}')
# Out:
#    25
#  1234
# 2006

# %%
a = 3.14159265
print(f'{a}, {a:.3f}')
print(f'{a:7.3f}')
# Out:
# 3.14159265, 3.142
#   3.142

# %%
# 원의 넓이 구하는 식
pi = 3.14159265
radius = int(input('원의 반지름: '))
area = pi * radius ** 2 #pi * radius * radius
print(f'반지름이 {radius}인 원의 넓이는 {area:.3f}')
# Out:
# 원의 반지름: 7
# 반지름이 7인 원의 넓이는 153.938

# %% [markdown]
# ## 4. 연산자 (Operators)
#
# 산술 연산자를 통해 데이터를 계산합니다.
#
# | 연산자 | 기능 | 예시 (a=10, b=3) | 결과 |
# | --- | --- | --- | --- |
# | `+` | 더하기 | `a + b` | 13 |
# | `-` | 빼기 | `a - b` | 7 |
# | `*` | 곱하기 | `a * b` | 30 |
# | `/` | 나누기 (실수) | `a / b` | 3.333... |
# | `//` | **몫** | `a // b` | 3 |
# | `%` | **나머지** | `a % b` | 1 |
# | `**` | 거듭제곱 | `a ** b` | 1000 |

# %%
a = int(input('정수: '))
b = int(input('정수: '))
print(f'{a} + {b} = {a+b}')
# Out:
# 정수: 6
# 정수: 4
# 6 + 4 = 10

# %%
print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b}')
print(f'{a} // {b} = {a//b}') # 몫
print(f'{a} % {b} = {a%b}') # 나머지
print(f'{a} ** {b} = {a**b}') # 6**4 = 6*6*6*6
# Out:
# 6 - 4 = 2
# 6 * 4 = 24
# 6 / 4 = 1.5
# 6 // 4 = 1
# 6 % 4 = 2

# %% [markdown]
# ### 연산자 우선 순위
# 우선순위와 관계없이 연산의 순서를 정하려면 **괄호**를 사용
#
# 1.   ** 거듭제곱
# 2.   +양수, -음수
# 3.   *,/,//, %
# 4. +, -
# 5. <, <=, >, >= 비교연산자
# 6. ==, != 동등연산자
# =, +=, -=, /=, //=, %=, **= 대입연산자
# 7. not 논리연산자
# 8. and 논리연산자
# 9. or 논리연산자

# %%
ave = (70 + 80 + 90) / 3
print(ave)
# Out:
# 80.0

# %%
a = 2
b = 3
c = 4
print(a + b ** c * a)
# Out:
# 164

# %%
# 남녀비율 계산하기
male_num = int(input('남성 지원자 수: '))
female_num = int(input('여성 지원자 수: '))
total = male_num + female_num
print(f'남성 비율: {male_num / total:.2f} 여성 비율: {female_num / total:.2f}')
# Out:
# 남성 지원자 수: 173
# 여성 지원자 수: 217
# 남성 비율: 0.44 여성 비율: 0.56

# %%
# 길이 단위 변환하기
cm = int(input('센티미터 단위 길이: '))
m = cm // 100
cm = cm % 100
print(f'{m}미터 {cm}센티미터')
# Out:
# 센티미터 단위 길이: 234
# 2미터 34센티미터

# %% [markdown]
# ## 5. [실습 예제]
# ### ⏱ 시간 단위 변환기
# 1. **데이터 입력**: 사용자로부터 초(second) 단위의 큰 숫자를 입력받아 정수로 변환합니다.
# 2. **시간/분 계산**:
#     * 전체 초를 3,600으로 나눈 **몫**을 '시간'으로 저장합니다.
#     * 남은 초를 다시 60으로 나눈 **몫**은 '분', **나머지**는 최종적인 '초'가 됩니다.
# 3. **결과 출력**: 계산된 시간, 분, 초를 조합하여 화면에 보여줍니다.

# %%
second = int(input('초 단위의 시간을 입력해주세요!'))
hour = second // 3600 # 60s = 1m, 60m = 1h, 3600s = 1h
second = second % 3600
minute = second // 60
second = second % 60
print(f'{hour}시간 {minute}분 {second}초')
# Out:
# 초 단위의 시간을 입력해주세요!8750
# 2시간 25분 50초

# %%
time = int(input('초 단위의 시간을 입력해주세요!'))
hour = time // 3600
minute = (time % 3600) // 60
second = (time % 3600) % 60
print(f'{hour}시간 {minute}분 {second}초')
# Out:
# 초 단위의 시간을 입력해주세요!5000
# 1시간 23분 20초 입니다.

# %% [markdown]
# ### 💰 주문 금액 계산기
# 1. **정보 입력**: 상품 가격과 주문 수량을 각각 입력받아 숫자로 변환합니다.
# 2. **금액 산출**: (상품 가격 × 수량) 로직을 통해 총 주문 금액을 계산합니다.
# 3. **포맷팅**: "총 주문 금액은 OOO원입니다"와 같은 형태로 가독성 있게 출력합니다.

# %% [markdown]
# ### 주문 금액 계산기
# 1. 음료 주문 수 입력 받기
# * americano 2000
# * latte 3000
# * greentea 2500
#
# 2. 주문 금액 출력 sum 출력

# %%
americano_price = 2000
latte_price = 3000
greentea_price = 2500

americano_count = int(input("아메리카노 주문 수량: "))
latte_count = int(input("라떼 주문 수량: "))
greentea_count = int(input("그린티 주문 수량: "))

sum = americano_count * americano_price + latte_price * latte_count + greentea_price * greentea_count
print(f"총 주문 금액은 {sum}원입니다")
# Out:
# 아메리카노 주문 수량: 1
# 라떼 주문 수량: 1
# 그린티 주문 수량: 1
# 총 주문 금액은 7500원입니다

# %% [markdown]
# ### 주문 금액 계산기
#
# 1. 음료 가격을 변수에 저장
#
#
# * americano_price = 2000
# * latte_price = 3000
# * greentea_price = 2500
