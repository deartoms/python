# %% [markdown]
# <a href="https://colab.research.google.com/github/deartoms/python/blob/main/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **148p 문제 3**

# %%
a = "python"
print(len(a))
# Out:
# 6

# %%
b = ""
print(len(b))
# Out:
# 0

# %%
c = "ABC＼nDEF"
print(len(c))
# Out:
# 8

# %%
d = [1, 2, 3]
print(len(d))
# Out:
# 3

# %%
e = [1, [2, 3]]
print(len(e))
# Out:
# 2

# %%
f = []
print(len(f))
# Out:
# 0

# %% [markdown]
# ### 문제 4

# %%
a = [1, 2, 3]
print(sum(a))
# Out:
# 6

# %%
b = [3, 4, 5]
print(sum(b, 1))
# Out:
# 13

# %%
c = [[1, 2] , [0], [9]]
print(sum(c, []))
# Out:
# [1, 2, 0, 9]

# %%
d = [4, 5, 6]
print(max(d))
# Out:
# 6

# %%
e = [4, 5, 6]
print(min(e))
# Out:
# 4

# %%
print(max(4, 5, 6))
# Out:
# 6

# %%
print(min(4, 5, 6))
# Out:
# 4

# %% [markdown]
# ### 149p 문제 5

# %%
a = [5, 4, 2, 6]
print(sorted(a))
# Out:
# [2, 4, 5, 6]

# %%
b = [5, 4, 2, 6]
print(sorted(b, reverse=True))
# Out:
# [6, 5, 4, 2]

# %%
c = ["orange", "apple", "grape"]
print(sorted(c))
# Out:
# ['apple', 'grape', 'orange']

# %%
d = ["orange", "apple", "grape"]
print(sorted(d, reverse=True))
# Out:
# ['orange', 'grape', 'apple']

# %%
e = ["orange", "apple", "Grape"]
print(sorted(e))
# Out:
# ['Grape', 'apple', 'orange']

# %%
f = sorted("apple")
print(f)
# Out:
# ['a', 'e', 'l', 'p', 'p']

# %% [markdown]
# ### 문제 6

# %%
a = 3
print("a = {}".format(a))
# Out:
# a = 3

# %%
a = 3
b = 4
print("b = {1}, a = {0}".format(a,b))
# Out:
# b = 4, a = 3

# %%
print("A = {a}, B = {b}".format(b=5,a=9))
# Out:
# A = 9, B = 5

# %%
print("A = {a}, B = {b}".format(a=9,b=5))
# Out:
# A = 9, B = 5
