# %% [markdown]
# <a href="https://colab.research.google.com/github/deartoms/python/blob/main/%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 연습문제 63p

# %%
string = "ABCDE"

# %%
str1 = string[1]
print(str1)
# Out:
# B

# %%
str2 = string[-1]
print(str2)
# Out:
# E

# %%
str3 = string[1:3]
print(str3)
# Out:
# BC

# %%
str4 = string[:3]
print(str4)
# Out:
# ABC

# %%
str5 = string[-2:]
print(str5)
# Out:
# DE

# %%
str6 = string[1:-2]
print(str6)
# Out:
# BC

# %% [markdown]
# ### 연습문제 P102

# %%
print(5 + 2)
# Out:
# 7

# %%
print(5 - 2)
# Out:
# 3

# %%
print(5 * 2)
# Out:
# 10

# %%
print(5 / 2)
# Out:
# 2.5

# %%
print(5 // 2)
# Out:
# 2

# %%
print(5 % 2)
# Out:
# 1

# %%
print(5 ** 2)
# Out:
# 25

# %%
print(5 * 2.0)
# Out:
# 10.0

# %%
print(5 + 2 * 3)
# Out:
# 11

# %%
print((5 + 2) * 3)
# Out:
# 21

# %%
print("Hello" + "World")
# Out:
# HelloWorld

# %%
print("Hello" * 2)
# Out:
# HelloHello

# %%
print("Hello" + "World" * 2)
# Out:
# HelloWorldWorld

# %%
print([1, 2] + [1, 1])
# Out:
# [1, 2, 1, 1]

# %%
print([1, 2] * 2)
# Out:
# [1, 2, 1, 2]

# %%
print([1, 2] + [1, 1] *2)
# Out:
# [1, 2, 1, 1, 1, 1]

# %% [markdown]
# ### 연습문제 147p

# %%
a = input
print(a)
# Out:
# 3
# 3

# %%
a = input()
b = int(a)
print(b * 2)
# Out:
# 3
# 6

# %%
a = int(input())
print(a * 2)
# Out:
# 3
# 6

# %%
a= abs(-5)
print(a)
# Out:
# 5

# %%
b = abs(5)
print(b)
# Out:
# 5

# %%
c = round(3.4)
print(c)
# Out:
# 3

# %%
d = round(3.5)
print(d)
# Out:
# 4

# %%
e = round(-5.2)
print(e)
# Out:
# -5

# %%
f = round(-5.5)
print(f)
# Out:
# -6

# %%
g = round(4.54, 1)
print(g)
# Out:
# 4.5
