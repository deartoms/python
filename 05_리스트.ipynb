# %% [markdown]
# <a href="https://colab.research.google.com/github/deartoms/python/blob/main/05_%EB%A6%AC%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 파이썬 기초: 05. 리스트

# %% [markdown]
# ## 1. 리스트의 개요
# * **개념**: 리스트(list)는 여러 개의 데이터를 하나의 이름으로 묶어서 저장하는 자료형입니다.
# * **필요성**: 역할이 비슷한 변수가 많아질 때 리스트를 사용하면 프로그램이 간결해지고 데이터 관리가 쉬워집니다.
# * **리스트 생성**: 대괄호 `[]`를 사용하며, 항목은 쉼표(`,`)로 구분합니다.
#     * 예: `prices = [1000, 2000, 3000]`
# * **항목 접근 (Indexing)**: 리스트의 각 항목은 인덱스 번호를 가지며, **0번부터 시작**합니다.
#     * 예: `prices[0]`은 첫 번째 항목인 1000을 의미합니다.

# %% [markdown]
# 리스트이름 = [항목item1, 항목item2, 항목item3]

# %%
prices = [1500, 3200, 2500, 4000, 5500]
for i in range(len(prices)): # 0, 1, 2, 3, 4
  prices[i] = prices[i] + prices[i]*0.05

  print(prices)
# Out:
# [1575.0, 3200, 2500, 4000, 5500]
# [1575.0, 3360.0, 2500, 4000, 5500]
# [1575.0, 3360.0, 2625.0, 4000, 5500]
# [1575.0, 3360.0, 2625.0, 4200.0, 5500]
# [1575.0, 3360.0, 2625.0, 4200.0, 5775.0]

# %%
menus = ['자장면, 짬뽕, 볶음밥']
print(menus)
# Out:
# ['자장면, 짬뽕, 볶음밥']

# %%
# 빈 리스트 생성 후 값 추가하기
menus = []
menus.append('자장면')
menus.append('짬뽕')
menus.append('볶음밥')
menus.append('탕수육')
print(menus)
# Out:
# ['자장면', '짬뽕', '볶음밥', '탕수육']

# %%
# cubes 리스트 , 1부터 10까지 정수를 세제곱한 수를 리스트 저장
cubes = []

for i in range(1, 11):
    cubes.append(i**3)

print(cubes)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %% [markdown]
# * 리스트 내포 (list comprehension): [] 안에 for문과 조건문을 내포시켜서 한줄로 생성
# * [식 for 변수 in 반복 가능한 것 if 조건식]

# %%
cubes = [i**3 for i in range(1,11)]

print(cubes)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
from typing import Sequence
# 1~100 중에서 7의 배수를 리스트 저장
sequence = []

for i in range(1, 101):
    if i % 7 == 0:
      sequence.append(i)
print(sequence)
# Out:
# [7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]

# %%
sequence = [i for i in range(1,101) if i%7 == 0]
print(sequence)
# Out:
# [7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]

# %%
score = [71,80,60,90,65]
result = []

for i in score:
  if i >= 70:
    result.append("합격")
  else:
    result.append("불합격")
print(result)
# Out:
# ['합격', '합격', '불합격', '합격', '불합격']

# %%
# 리스트 내포
score = [71,80,60,90,65]
result = ["합격" if i >= 70 else "불합격" for i in score]
print(result)
# Out:
# ['합격', '합격', '불합격', '합격', '불합격']

# %% [markdown]
# ## 2. 리스트 생성과 인덱싱
#
# * **생성**: 대괄호(`[]`)를 사용하며, 각 요소는 쉼표(`,`)로 구분합니다.
#     * 예: `fruits = ['apple', 'banana', 'cherry']`
# * **인덱싱**: 리스트의 각 요소에 접근하기 위한 번호표로, **0번**부터 시작합니다.
#     * `fruits[0]`은 'apple', `fruits[1]`은 'banana'를 가리킵니다.

# %% [markdown]
# * len(리스트):리스트의 길이, 항목의 전체 개수를 반환
# * enumerate(): 인덱스와 항목을 모두 반환

# %%
print(menus[2])

print(menus)
print(menus[-1])
print(menus[-2])
print(menus[-3])

for i in range(len(menus)):
  print(menus[i])
for item in menus:
  print(item)
for i, item in enumerate(menus):
  print(i, item)
# Out:
# 볶음밥
# ['자장면', '짬뽕', '볶음밥', '탕수육']
# 탕수육
# 볶음밥
# 짬뽕
# 자장면
# 짬뽕
# 볶음밥
# 탕수육
# 자장면
# 짬뽕
# 볶음밥
# 탕수육
# 0 자장면
# 1 짬뽕
# 2 볶음밥
# 3 탕수육

# %% [markdown]
# * 슬라이싱(slicing) : 리스트의 일부 항목 추출
# * 리스트[시작 인덱스:종료 인덱스]

# %%
letters= ['A', 'B', 'C', 'D', 'E']
print(letters[1:3])
# A,B,C,D
print(letters[:4]) #letters[0:4]
# C,D,E
print(letters[2:])
# B,C,D
print(letters[1:-1])
# Out:
# ['B', 'C']
# ['A', 'B', 'C', 'D']
# ['C', 'D', 'E']
# ['B', 'C', 'D']

# %% [markdown]
# ## 3. 리스트 주요 메서드
#
# 리스트의 요소를 추가, 수정, 삭제하는 다양한 기능을 제공합니다.
#
# * **추가**: `.append(값)` (끝에 추가), `.insert(위치, 값)` (특정 위치에 삽입), `.extend(리스트)` (다른 리스트와 합침)
# * **삭제**: `.remove(값)` (첫 번째 일치하는 값 삭제), `.pop(위치)` (특정 위치의 값을 꺼내고 리스트에서 제거)

# %%
pl = []
pl.append('파이썬')
pl.append('자바')
pl.append('C++')
pl.append('C')
print(pl)
# Out:
# ['파이썬', '자바', 'C++', 'C']

# %%
pets = ['강아지','고양이','햄스터','도마뱀']
select1 = pets.pop(3)
print(select1)
print(pets)

select2 = pets.pop() # 마지막 인덱스 항목 삭제
print(select2)
print(pets)

del pets[0] # del 키워드는 삭제한 항목은 반환되지 않음
print(pets)
# Out:
# 도마뱀
# ['강아지', '고양이', '햄스터']
# 햄스터
# ['강아지', '고양이']
# ['고양이']

# %%
pets = ['강아지','고양이','햄스터','도마뱀','강아지']
pets.remove('강아지') # 첫번째로 일치하는 항목만 삭제
print(pets)

pets.clear() # 모든 항목 삭제
print(pets)
# Out:
# ['고양이', '햄스터', '도마뱀', '강아지']
# []

# %% [markdown]
# ## 4. 리스트 탐색 및 정렬
#
# * **탐색**: `len(리스트)` (길이 확인), `.count(값)` (특정 값의 개수 확인)
# * **정렬**: `.sort()` (원본 리스트를 오름차순 정렬), `sorted(리스트)` (정렬된 새로운 리스트 반환)

# %%
# sort() 원본을 직접 오름차순 정렬, 내림차순, sort(reserve=True)
numbers = [3, 1, 4, 2]
numbers.sort()
print(numbers)
numbers.sort(reverse=True)
print(numbers)

# sorted() 원본을 유지, 정렬된 새로운 리스트를 반환, 내림차순 sorted(리스트, reserve=True)
numbers_sorted = [5, 6, 7, 9]
new_numbers = sorted(numbers_sorted)
print(numbers_sorted)
print(new_numbers)
new_numbers2 = sorted(numbers_sorted, reverse=True)
print(new_numbers2)
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]
# [5, 6, 7, 9]
# [5, 6, 7, 9]
# [9, 7, 6, 5]

# %%
# .reverse() 리스트를 역순으로
nations = ['한국', '미국', '일본', '중국']
nations.reverse()
print(nations)
# Out:
# ['중국', '일본', '미국', '한국']

# %%
# 값 in 리스트 : 리스트에 값이 있으면 True, 없으면 False
months = ['January', 'February', 'March', 'April', 'May','June'
          'July', 'August','September','October','November','December']
answer = input('월(영어): ')

if answer in months:
  print(f'{months.index(answer)+1}월')
else:
  print('잘못 입력했습니다')

# 리스트,index(값) : 리스트에 값이 있으면 해당 항목의 인덱스를 반환
# Out:
# 월(영어): April
# 4월

# %%
import random
colors = ['red','green','blue','yellow','purple']

# random.choice(리스트) : 리스트에서 항목 한개를 무작위로 선택
print(random.choice(colors))

# random.sample(리스트, 개수) : 리스트 항목에서 개수 만큼 중복 없이 무작위로 선택
print(random.sample(colors, 3))

# random.choices(리스트, k=개수): 중복 허용
print(random.choices(colors, k=3))

# random.shuffle(리스트)
random.shuffle(colors)
print(colors)
# Out:
# blue
# ['purple', 'green', 'red']
# ['purple', 'blue', 'green']
# ['red', 'yellow', 'green', 'purple', 'blue']

# %%
# 로또 번호 생성
# 1~45 숫자 생성 배열에 저장
# 중복 없이 무작위로 6개 숫자만 선택
# 새로운 배열에 추가
all_numbers = []

for i in range(1,46):
  all_numbers.append(i)

random.shuffle(all_numbers)
print(all_numbers)

result_numbers = random.sample(all_numbers, 6)
print(result_numbers)
# Out:
# [10, 9, 41, 23, 44, 16, 34, 27, 19, 40, 38, 30, 31, 33, 39, 35, 4, 5, 21, 14, 20, 43, 7, 42, 13, 28, 26, 12, 11, 45, 2, 6, 24, 1, 18, 17, 29, 32, 25, 3, 22, 36, 15, 8, 37]
# [24, 33, 29, 15, 30, 7]

# %%
scores = [85,95,70,75,99,93,88]

# max() : 리스트 항목에서 최대값
print(f'최대값: {max(scores)}')

# min() : 리스트 항목에서 최소값
print(f'최소값: {min(scores)}')

# sum() : 리스트 항목들의
print(f'합계: {sum(scores)}')

print(f'평균: {sum(scores)/len(scores)}')
# Out:
# 최대값: 99
# 최소값: 70
# 합계: 605
# 평균: 86.42857142857143

# %%
# count(): 리스트에서 특정 값이 몇개 있는지 개수 반환
fruits = ['apple', 'banana', 'apple', 'cherry', 'apple']
apple_count = fruits.count('apple')
print(f'사과 개수:{apple_count}')
# Out:
# 사과 개수:3

# %%
# 문제: 3개의 이름을 입력 받아서 names 리스트에 저장하고 정렬하고 출력
names = []

for i in range(3):
    name = input('이름: ')
    names.append(name)

names.sort()

print(f'정렬된 이름: {names}')

# %%
# 문제: 거꾸로 항목 하나씩 출력하기
pi = ['python', 'C', 'java']
for i in range(len(pi)-1,-1,-1):
  print(pi[i])
# Out:
# java
# C
# python

# %%
# 학생수 만큼 입력받은 학생 명단에서 무작위로 중복없이 두명만 선택
import random

names = []
num = int(input('학생 수: '))

for i in range(num):
    name = input('이름 입력: ')
    names.append(name)

selected = random.sample(names, 2)

print(f'선택된 학생: {selected}')
# Out:
# 학생 수: 3
# 이름 입력: 김태환
# 이름 입력: 고준혁
# 이름 입력: 이용진
# 선택된 학생: ['고준혁', '김태환']

# %%
element_symbol = ['H','He','Li','Be','B','C','N','O','F','Ne',
'Na','Mg','Al','Si','P','S','Cl','Ar','K','Ca',
'Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu','Zn',
'Ga','Ge','As','Se','Br','Kr','Rb','Sr','Y','Zr',
'Nb','Mo','Tc','Ru','Rh','Pd','Ag','Cd','In','Sn',
'Sb','Te','I','Xe','Cs','Ba','La','Ce','Pr','Nd',
'Pm','Sm','Eu','Gd','Tb','Dy','Ho','Er','Tm','Yb',
'Lu','Hf','Ta','W','Re','Os','Ir','Pt','Au','Hg',
'Tl','Pb','Bi','Po','At','Rn','Fr','Ra','Ac','Th',
'Pa','U','Np','Pu','Am','Cm','Bk','Cf','Es','Fm',
'Md','No','Lr','Rf','Db','Sg','Bh','Hs','Mt','Ds',
'Rg','Cn','Nh','Fl','Mc','Lv','Ts','Og']

element_name = ['수소','헬륨','리튬','베릴륨','붕소','탄소','질소','산소','플루오린','네온',
'나트륨','마그네슘','알루미늄','규소','인','황','염소','아르곤','칼륨','칼슘',
'스칸듐','타이타늄','바나듐','크로뮴','망가니즈','철','코발트','니켈','구리','아연',
'갈륨','저마늄','비소','셀레늄','브로민','크립톤','루비듐','스트론튬','이트륨','지르코늄',
'나이오븀','몰리브데넘','테크네튬','루테늄','로듐','팔라듐','은','카드뮴','인듐','주석',
'안티모니','텔루륨','아이오딘','제논','세슘','바륨','란타넘','세륨','프라세오디뮴','네오디뮴',
'프로메튬','사마륨','유로퓸','가돌리늄','터븀','디스프로슘','홀뮴','어븀','툴륨','이터븀',
'루테튬','하프늄','탄탈럼','텅스텐','레늄','오스뮴','이리듐','백금','금','수은',
'탈륨','납','비스무트','폴로늄','아스타틴','라돈','프랑슘','라듐','악티늄','토륨',
'프로탁티늄','우라늄','넵투늄','플루토늄','아메리슘','퀴륨','버클륨','칼리포늄','아인슈타이늄','페르뮴',
'멘델레븀','노벨륨','로렌슘','러더포듐','더브늄','시보귬','보륨','하슘','마이트너륨','다름슈타듐',
'뢴트게늄','코페르니슘','니호늄','플레로븀','모스코븀','리버모륨','테네신','오가네손']

# %%
print(len(element_symbol))

for i in range(len(element_symbol)):
  print(element_symbol[i], element_name[i])
# Out:
# 118
# H 수소
# He 헬륨
# Li 리튬
# Be 베릴륨
# B 붕소
# C 탄소
# N 질소
# O 산소
# F 플루오린
# Ne 네온
# Na 나트륨
# Mg 마그네슘
# Al 알루미늄
# Si 규소
# P 인
# S 황
# Cl 염소
# Ar 아르곤
# K 칼륨
# Ca 칼슘
# Sc 스칸듐
# Ti 타이타늄
# V 바나듐
# Cr 크로뮴
# Mn 망가니즈
# Fe 철
# Co 코발트
# Ni 니켈
# Cu 구리
# Zn 아연
# Ga 갈륨
# Ge 저마늄
# As 비소
# Se 셀레늄
# Br 브로민
# Kr 크립톤
# Rb 루비듐
# Sr 스트론튬
# Y 이트륨
# Zr 지르코늄
# Nb 나이오븀
# Mo 몰리브데넘
# Tc 테크네튬
# Ru 루테늄
# Rh 로듐
# Pd 팔라듐
# Ag 은
# Cd 카드뮴
# In 인듐
# Sn 주석
# Sb 안티모니
# Te 텔루륨
# I 아이오딘
# Xe 제논
# Cs 세슘
# Ba 바륨
# La 란타넘
# Ce 세륨
# Pr 프라세오디뮴
# Nd 네오디뮴
# Pm 프로메튬
# Sm 사마륨
# Eu 유로퓸
# Gd 가돌리늄
# Tb 터븀
# Dy 디스프로슘
# Ho 홀뮴
# Er 어븀
# Tm 툴륨
# Yb 이터븀
# Lu 루테튬
# Hf 하프늄
# Ta 탄탈럼
# W 텅스텐
# Re 레늄
# Os 오스뮴
# Ir 이리듐
# Pt 백금
# Au 금
# Hg 수은
# Tl 탈륨
# Pb 납
# Bi 비스무트
# Po 폴로늄
# At 아스타틴
# Rn 라돈
# Fr 프랑슘
# Ra 라듐
# Ac 악티늄
# Th 토륨
# Pa 프로탁티늄
# U 우라늄
# Np 넵투늄
# Pu 플루토늄
# Am 아메리슘
# Cm 퀴륨
# Bk 버클륨
# Cf 칼리포늄
# Es 아인슈타이늄
# Fm 페르뮴
# Md 멘델레븀
# No 노벨륨
# Lr 로렌슘
# Rf 러더포듐
# Db 더브늄
# Sg 시보귬
# Bh 보륨
# Hs 하슘
# Mt 마이트너륨
# Ds 다름슈타듐
# Rg 뢴트게늄
# Cn 코페르니슘
# Nh 니호늄
# ...

# %%
# 문제: 원소 검색기
# while문 사용 반복,
#'원소 기호 : H, 원소 이름: 수소, 종료' 입력 받고
# 만약에 입력받은 값이 종료 이면 '종료합니다' 출력 후 반복문 종료
# 원소 기호를 입력 받은 경우, 입력 받은 원소 기호가 리스트에 있으면
# 해당 원소 기호의 인덱스 번호를 찾아서 인덱스 번호에 해당하는 원자 번호와 원소 이름을 출력
# 원소 이름을 입력 받은 경우, 입력 받은 원소 이름이 리스트에 있으면
# 해당 원소 이름의 인덱스 번호를 찾아서 인덱스 번호에 해당하는 원자 번호와 원소 기호를 출력

# 출력 예시
# 원자 번호:1, 원소 이름: 수소
# 원자 번호:1, 원소 기호: H

# %%
while True:
  answer = input('원소 기호: H, 원소 이름: 수소, 종료: ')
  if answer == '종료':
    print('종료합니다')
    break
  elif answer in element_symbol:
    idx = element_symbol.index(answer)
    print(f'원자 번호: {idx+1}, 원소 이름: {element_name[idx]}')
  elif answer in element_name:
    idx = element_name.index(answer)
    print(f'원자 번호: {idx+1}, 원소 기호: {element_symbol[idx]}')
  else:
    print('잘못 입력했습니다')
# Out:
# 원소 기호: H, 원소 이름: 수소, 종료: 탄소
# 원자 번호: 6, 원소 기호: C
# 원소 기호: H, 원소 이름: 수소, 종료: 수소
# 원자 번호: 1, 원소 기호: H
# 원소 기호: H, 원소 이름: 수소, 종료: 산소
# 원자 번호: 8, 원소 기호: O
# 원소 기호: H, 원소 이름: 수소, 종료: 종료
# 종료합니다

# %% [markdown]
# ## 5. [실습 예제]
#
# ## 삼각비 값 찾기 사전
# 리스트의 인덱싱 기능을 활용하여 특정 각도에 대한 삼각비 값을 출력하는 프로그램을 만들어 봅니다.
# ### 코드 로직
# 1. **데이터 저장**: 15개의 삼각비 명칭과 그에 대응하는 값을 리스트에 각각 저장합니다.
# 2. **사용자 입력**: 사용자로부터 0~14 사이의 인덱스 번호를 입력받습니다.
# 3. **결과 출력**: 입력받은 번호를 리스트의 인덱스로 사용하여 해당 각도와 값을 매칭해 보여줍니다.

# %%
# 삼각비 검색기
angles = ['sin0', 'sin30', 'sin45', 'sin60', 'sin90',
          'cos0','cos30', 'cos45', 'cos60', 'cos90',
          'tan0', 'tan30', 'tan45', 'tan60', 'tan90']
values = ['0','1/2','√2/2', '√3/2', '1', #sin 0~90
          '1','√3/2', '√2/2', '1/2', '0', #cos 0~90
          '0','√3/3', '1', '√3', '정의 되지 않음'] #tan 0-90

# %%
# zip 함수를 사용하여 이름과 값을 짝찌어 출력
for name, val in zip(angles, values):
  print(f'{name} = {val}')
# Out:
# sin0 = 0
# sin30 = 1/2
# sin45 = √2/2
# sin60 = √3/2
# sin90 = 1
# cos0 = 1
# cos30 = √3/2
# cos45 = √2/2
# cos60 = 1/2
# cos90 = 0
# tan0 = 0
# tan30 = √3/3
# tan45 = 1
# tan60 = √3
# tan90 = 정의 되지 않음

# %%
# while문 사용 반복
# 입력받기 '삼각비 입력하세요: sin0, 종료'
# angles 리스트에 해당 삼각비가 있으면 인덱스 번호를 찾아서
# 인덱스 번호에 해당되는 values 리스트 값을 출력

# 출력 예시
# sin0 = 0

# %% [markdown]
# ## 원소 검색기
# 1. **이중 리스트 구조**: 원소 기호 리스트(`element_symbol`)와 원소 이름 리스트(`element_name`)를 별도로 만듭니다.
# 2. **반복문 결합**: `for` 문과 `range(len(리스트))`를 사용하여 전체 원소 기호와 이름을 짝지어 출력합니다.
# 3. **검색 로직**:
#     * 사용자가 원소 기호(예: 'H')를 입력합니다.
#     * 기호 리스트에서 해당 기호의 위치(`index`)를 찾습니다.
#     * 찾은 인덱스를 이름 리스트에 적용하여 '수소'를 출력합니다.
